# %%
import pandas as pd
df = pd.read_csv('restaurant_details.csv')
df
# Out:
# C:\Users\SRIJAN\AppData\Local\Temp\ipykernel_24040\1291410968.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#                      Restaurant Name Rating  \
# 0                    La Pino'z Pizza    3.3
# 1            Mango Masala Restaurant    4.6
# 2                     Domino's Pizza    3.8
# 3                        Mango Curry    4.3
# 4           Rominus Pizza And Burger    3.1
# ..                               ...    ...
# 412                Roma's Café Diner    4.9
# 413            Pizzeria Vaatika Cafe    4.1
# 414  Champaran Desi Matka Meat House      -
# 415                     Hotel Kalika    3.8
# 416                  Barbeque Nation    4.9
#
#                                                Cuisine Average Cost for Two  \
# 0                     Pizza, Pasta, Italian, Fast Food         ₹400 for two
# 1    North Indian, South Indian, Fast Food, Sandwic...         ₹600 for two
# 2           Pizza, Fast Food, Desserts, Italian, Pasta         ₹400 for two
# 3       North Indian, Continental, Desserts, Beverages         ₹500 for two
# 4               Pizza, Burger, Pasta, Wraps, Fast Food         ₹600 for two
# ..                                                 ...                  ...
# 412  Cafe, Continental, North Indian, Italian, Asia...         ₹800 for two
# 413  Pizza, Fast Food, Chinese, Pasta, North Indian...         ₹500 for two
# 414            Mughlai, Bihari, Lucknowi, North Indian         ₹500 for two
# 415        North Indian, Chinese, Street Food, Biryani         ₹400 for two
# 416  North Indian, BBQ, Biryani, Kebab, Continental...       ₹1,700 for two
#
#          City                      Address   Latitude  Longitude
# 0       Ajmer        Ana Sagar Lake, Ajmer  26.484070  74.631360
# 1       Ajmer           India Motor, Ajmer  26.465028  74.639004
# 2       Ajmer          Pal Bhichala, Ajmer  26.465445  74.637703
# 3       Ajmer           India Motor, Ajmer  26.465067  74.639097
# 4       Ajmer        Ana Sagar Lake, Ajmer  26.481131  74.631208
# ..        ...                          ...        ...        ...
# 412  Varanasi              Lanka, Varanasi  25.281143  83.003505
# 413  Varanasi          Assi Ghat, Varanasi  25.288894  83.006085
# 414  Varanasi            Nadesar, Varanasi  25.339418  82.981964
# 415  Varanasi            Nadesar, Varanasi  25.335272  82.985533
# 416  Varanasi  JHV Mall, Nadesar, Varanasi  25.335647  82.978038
#
# [417 rows x 8 columns]

# %%
df[df['City']=='Agra']
# Out:
#                    Restaurant Name Rating  \
# 9                 Molecule Air Bar    4.6
# 10     The Salt Cafe Kitchen & Bar    4.9
# 11                       Palm Burj    4.5
# 12             Unplugged Courtyard    4.4
# 13                       Pizza Hut    3.8
# 14                        Momocult    3.7
# 15                             KFC    3.9
# 16  Lights Out - Lounge & Roofpark    4.1
# 17                  New Pizza King    3.8
#
#                                               Cuisine Average Cost for Two  \
# 9         North Indian, Chinese, Continental, Italian       ₹2,000 for two
# 10  North Indian, Continental, Chinese, Italian, F...       ₹1,800 for two
# 11  North Indian, Chinese, Continental, Sushi, Sic...       ₹2,200 for two
# 12  Mediterranean, North Indian, Continental, Chin...       ₹1,600 for two
# 13              Pizza, Fast Food, Desserts, Beverages       ₹1,000 for two
# 14                          Momos, Chinese, Fast Food         ₹200 for two
# 15    Burger, Fast Food, Biryani, Desserts, Beverages         ₹500 for two
# 16  Bar Food, Finger Food, North Indian, Chinese, ...       ₹1,400 for two
# 17                                   Pizza, Fast Food         ₹500 for two
#
#     City            Address   Latitude  Longitude
# 9   Agra      Tajganj, Agra  27.154239  78.059235
# 10  Agra      Tajganj, Agra  27.157624  78.049410
# 11  Agra    Rakabganj, Agra  27.163906  78.014302
# 12  Agra      Tajganj, Agra  27.158769  78.061784
# 13  Agra   Agra Cantt, Agra  27.158996  78.013175
# 14  Agra  Civil Lines, Agra  27.201438  78.007533
# 15  Agra      Tajganj, Agra  27.157827  78.049727
# 16  Agra  Civil Lines, Agra  27.199522  78.007643
# 17  Agra   Dayal Bagh, Agra  27.215200  78.006378

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
driver = webdriver.Edge()



from selenium import webdriver
from selenium.webdriver.common.by import By
driver = webdriver.Edge()
driver.get(r"C:\Users\SRIJAN\OneDrive - S. Jaykishan\Desktop\Project Data\Trending dining restaurants in Agra - Zomato.html")
rest = driver.find_element(By.XPATH, '//*[@id="root"]/div/div[10]/div/div[1]/div/div/a[2]')  
restaurant_name = rest.text
restaurant_url = rest.get_attribute('href')

print("Restaurant Name:", restaurant_name)
print("Restaurant URL:", restaurant_url)



rating_1 = 0
star_elements = driver.find_elements(By.XPATH, '//*[@id="root"]/div/main/div/section[4]/section/section[2]/section[2]/div[2]/div[1]/div/div/div[2]/div/div/div[1]/div/i')

try:
    for star in range(len(star_elements)):
        html_string = star_elements[star].get_attribute('innerHTML')
        soup = BeautifulSoup(html_string, 'lxml')
        fill_value = soup.svg['fill']
        title_text = soup.title.text
        if fill_value == '#F3C117' and title_text == 'star-fill':
            rating_1 += 1
        else:
            rating_1 +=0
except Exception as e:
    print(f"Error: {e}")

    soup = BeautifulSoup(html_string, 'html.parser')
    linear_gradient = soup.find('linearGradient')
    linear_gradient= soup.svg.lineargradient
    stops = linear_gradient.find_all('stop')
    percentage = stops[1]['offset']
    decimal_rating = int(percentage.strip('%')) / 100

    rating_1 = decimal_rating

print( 'rating::', rating_1)
# Out:
# Restaurant Name: The Nawaabs
# 4.3
# star-fill
# Mughlai, North Indian, Biryani, Kebab, Beverages
# ₹1,100 for two
# Tajganj, Agra
# 2.7 km
# Restaurant URL: https://www.zomato.com/agra/the-nawaabs-tajganj/info
# rating:: 0
